# %%
#Angad Singh Hoonjan
#RA2111053010021
import pandas as pd
students=pd.read_csv(r"E:\Python for Data Science\Experiment 11\studentdetails.csv")
print(students)
import seaborn as sns
import matplotlib.pyplot as plt
g = sns.FacetGrid(students, hue="student_gender", palette="Set1", height=5)
g.map(plt.scatter, "gpa", "computer", s=150, linewidth=0.5,edgecolor="black")
g.add_legend()
# Out:
#   student_gender  TV  computer  sleep  exercise  gpa
# 0         Female   8         5      9         2  3.8
# 1           Male   7         9      6         2  2.5
# 2           Male   6         8      7         3  4.0
# 3         Female   9         8      6         1  2.3
# 4           Male   7         7      8         2  4.0

# %%
#Angad Singh Hoonjan
#RA2111053010021
from pandas.plotting import bootstrap_plot
import numpy as np
bootstrap_plot(pd.Series(np.random.uniform(size=200)));

# %%
#Angad Singh Hoonjan
#RA2111053010021
from pandas.plotting import autocorrelation_plot
import numpy as np
autocorrelation_plot(pd.Series(np.random.uniform(size=200)))
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
#Angad Singh Hoonjan
#RA2111053010021
from pandas.plotting import lag_plot
import numpy as np
lag_plot(pd.Series(np.random.uniform(size=200)))
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %%
#Angad Singh Hoonjan
#RA2111053010021
from pandas.plotting import boxplot
import numpy as np
boxplot(pd.Series(np.random.uniform(size=200)))
# Out:
# <Axes: >
